# %% [markdown]
# # Slidin' Videos: Use high-precision text tracking and semantic segmentation for chapters generation
#
# #### Please register for the Slidin' Videos challenge to get download URLs used in this notebook

# %% [markdown]
# ## 1. Deeplab finetuning
# #### DeepLabV3 model is a pretrained model for semantic segmentation of images. We will finetune it on Slidin' Videos dataset of slide titles

# %%
# !git clone https://github.com/msminhas93/DeepLabv3FineTuning.git
# !pip install torch torchvision pandas scikit-learn
# !pip install opencv-python-headless Shapely Pillow easyocr
# Out:
# fatal: destination path 'DeepLabv3FineTuning' already exists and is not an empty directory.
# Requirement already satisfied: torch in /home/capitaindata/anaconda3/lib/python3.10/site-packages (2.0.0)
# Requirement already satisfied: torchvision in /home/capitaindata/anaconda3/lib/python3.10/site-packages (0.15.1)
# Requirement already satisfied: pandas in /home/capitaindata/anaconda3/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: scikit-learn in /home/capitaindata/anaconda3/lib/python3.10/site-packages (1.2.1)
# Requirement already satisfied: filelock in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (3.9.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: jinja2 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (11.7.101)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (2.14.3)
# Requirement already satisfied: triton==2.0.0 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (2.0.0)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (11.7.91)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: networkx in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (2.8.4)
# Requirement already satisfied: typing-extensions in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (4.4.0)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: sympy in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch) (1.11.1)
# Requirement already satisfied: wheel in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.38.4)
# Requirement already satisfied: setuptools in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (65.6.3)
# Requirement already satisfied: lit in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from triton==2.0.0->torch) (16.0.1)
# Requirement already satisfied: cmake in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from triton==2.0.0->torch) (3.26.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torchvision) (9.0.1)
# Requirement already satisfied: requests in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: numpy in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torchvision) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: scipy>=1.3.2 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: six>=1.5 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from requests->torchvision) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: mpmath>=0.19 in /home/capitaindata/anaconda3/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg (from sympy->torch) (1.2.1)
# Requirement already satisfied: opencv-python-headless in /home/capitaindata/anaconda3/lib/python3.10/site-packages (4.5.4.60)
# Requirement already satisfied: Shapely in /home/capitaindata/anaconda3/lib/python3.10/site-packages (1.8.5.post1)
# Requirement already satisfied: Pillow in /home/capitaindata/anaconda3/lib/python3.10/site-packages (9.0.1)
# Requirement already satisfied: easyocr in /home/capitaindata/anaconda3/lib/python3.10/site-packages (1.6.2)
# Requirement already satisfied: numpy>=1.21.2 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from opencv-python-headless) (1.23.5)
# Requirement already satisfied: torch in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from easyocr) (2.0.0)
# Requirement already satisfied: pyclipper in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from easyocr) (1.3.0.post4)
# Requirement already satisfied: scikit-image in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from easyocr) (0.19.3)
# Requirement already satisfied: ninja in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from easyocr) (1.11.1)
# Requirement already satisfied: PyYAML in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from easyocr) (6.0)
# Requirement already satisfied: scipy in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from easyocr) (1.10.0)
# Requirement already satisfied: torchvision>=0.5 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from easyocr) (0.15.1)
# Requirement already satisfied: python-bidi in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: requests in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: triton==2.0.0 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (2.0.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (11.7.99)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (10.2.10.91)
# Requirement already satisfied: sympy in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (1.11.1)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (2.14.3)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (11.4.0.1)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (11.10.3.66)
# Requirement already satisfied: jinja2 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: typing-extensions in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (4.4.0)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (10.9.0.58)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (11.7.4.91)
# Requirement already satisfied: filelock in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (3.9.0)
# Requirement already satisfied: networkx in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (2.8.4)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (11.7.91)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from torch->easyocr) (11.7.101)
# Requirement already satisfied: wheel in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (0.38.4)
# Requirement already satisfied: setuptools in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->easyocr) (65.6.3)
# Requirement already satisfied: cmake in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from triton==2.0.0->torch->easyocr) (3.26.3)
# Requirement already satisfied: lit in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from triton==2.0.0->torch->easyocr) (16.0.1)
# Requirement already satisfied: six in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from scikit-image->easyocr) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from scikit-image->easyocr) (22.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: imageio>=2.4.1 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from scikit-image->easyocr) (2.26.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from jinja2->torch->easyocr) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /home/capitaindata/anaconda3/lib/python3.10/site-packages (from requests->torchvision>=0.5->easyocr) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /home/capitaindata/anaconda3/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg (from sympy->torch->easyocr) (1.2.1)

# %% [markdown]
# #### Download title masks collection and unzip it to the cloned repository.

# %%
# !unzip -q Train.zip -d DeepLabv3FineTuning/

# %% [markdown]
# #### Training DeepLab model: our goal is to maximize test_f1_score
# #### You may want to play with number of epochs, learning rate and loss function to get better results

# %%
# %cd DeepLabv3FineTuning
from pathlib import Path

#from segmentation_models_pytorch.losses.jaccard  import JaccardLoss
#from segmentation_models_pytorch.losses.constants import BINARY_MODE
#criterion = JaccardLoss(mode=BINARY_MODE)

import torch
from sklearn.metrics import f1_score, roc_auc_score
from torch.utils import data

import datahandler
from model import createDeepLabv3
from trainer import train_model

# Create the deeplabv3 resnet101 model which is pretrained on a subset
# of COCO train2017, on the 20 categories that are present in the Pascal VOC dataset.
model = createDeepLabv3()
model.train()


data_directory = Path("Train")
# Create the experiment directory if not present
exp_directory = Path("DemoExp")
if not exp_directory.exists():
    exp_directory.mkdir()

epochs = 10 

# Specify the evaluation metrics
metrics = {'f1_score': f1_score, 'auroc': roc_auc_score}

# Create the dataloader
dataloaders = datahandler.get_dataloader_single_folder(
    data_directory, fraction=0.2, image_folder="Images", 
    mask_folder="Masks", batch_size=2)



# Specify the loss function
criterion = torch.nn.MSELoss(reduction='mean')

# Specify the optimizer with a lower learning rate
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
_ = train_model(model, 
                criterion,
                dataloaders,
                optimizer,
                bpath=exp_directory,
                metrics=metrics,
                num_epochs=epochs)

# Save the trained model
torch.save(model, exp_directory / 'weights.pt')

# Terminate
exit()
# %cd ../
# Out:
# Epoch 1/10
# ----------
#   4%|█▋                                      | 37/854 [21:26<7:53:18, 34.76s/it]

# %% [markdown]
# ## 2. Making the submission
# #### Unpack the testset

# %%
# !unzip -q Test.zip

# %% [markdown]
# #### Load finetuned deeplab model and define helper functions

# %%
import glob
import os
import json
import cv2    
import torch
import numpy as np
import pandas as pd

from torchvision import transforms  
from PIL import Image

deeplab_width = 768
deeplab_height = 432
deeplab = torch.load('DeepLabv3FineTuning/DemoExp/weights.pt')
deeplab.eval()
     

def boxify(out, boxes):
    return [ torch.mean(out[b[0]:b[1], b[2]:b[3]]).item()  for b in boxes ]      

def titlesegment(image, boxes):
    # Resize the frame to the training input size
    inputs = transforms.ToTensor()(Image.fromarray(image, mode="RGB"))
    inputs = inputs.reshape(1, *inputs.shape).to('cuda')
    
    with torch.set_grad_enabled(False):
        outputs = deeplab(inputs)
        out = outputs['out'][0][0]
        box_scores = boxify(out, boxes)
        return out, np.array(box_scores)
    
def occupation(boxes):
    area = lambda b: (b[1]-b[0]) * (b[3]-b[2])
    y1, y2 = min([b[0] for b in boxes ]), max([b[1] for b in boxes ])
    x1, x2 = min([b[2] for b in boxes ]), max([b[3] for b in boxes ])
    return 1.0 * sum([ area(b) for b in boxes ]) / area([y1, y2, x1, x2])

# Locates a paragraph of text with the highest probability 
# to be a slide title 
def pickonetitle(boxes, scores):
    if len(boxes) == 0:
        return []
        
    best_idx = np.argmax(scores)
    best = boxes[best_idx]

    candidates = { i for i, box in enumerate(boxes) 
        if abs(box['fontsize']-best['fontsize']) <= best['fontsize'] * 0.25 
            and scores[best_idx] - scores[i] < 0.6 }
    
    while occupation([ boxes[i]['bbox'] for i in candidates ]) < 0.75:
        combinations = [ candidates - {j} for j in candidates if j != best_idx ]
        candidates = max(combinations, 
            key=lambda comb: occupation([ boxes[j]['bbox'] for j in comb ]))
            
    title_boxes = [ boxes[i] for i in candidates ]
    return title_boxes

# %% [markdown]
# #### Now, we're going to use EasyOCR package to "read" the titles. Modern OCR solutions may still produce a handful of errors, which is why you're encouraged to apply a language model or alternative OCR model to fix possible misspelings.

# %%
from shapely.geometry import Polygon, LineString

import easyocr
reader = easyocr.Reader(['en']) 

def sameline(a, b):
    return ((min(a['bbox'][1], b['bbox'][1]) - max(a['bbox'][0], b['bbox'][0]))
            / min(a['height'], b['height'])) >= 0.8
            
def isbelow(a, b):
    return not sameline(a, b) and a['bbox'][0] > b['bbox'][0]  
    
def isright(a, b):
    return sameline(a, b) and a['bbox'][2] > b['bbox'][2]  

def sort_boxes(boxes):              
    boxes_ = []
    for b in boxes:
        i = 0
        while i < len(boxes_) and (isbelow(b, boxes_[i]) or isright(b, boxes_[i])):
            i += 1
        boxes_.insert(i, b)
    return boxes_

def _norm_bbox(bbox):
    return  [ int(max(0, min([ p[1] for p in bbox ]))), 
              int(max([ p[1] for p in bbox ])), 
              int(max(0, min([ p[0] for p in bbox ]))), 
              int(max([ p[0] for p in bbox ])) ]

def process_ocr(ocr_results):
    items = []
    for bbox, text, conf in ocr_results:
        if text == '' or conf <= 0:
            continue  
        if not isinstance(bbox, list):
            bbox = bbox.tolist()
        item = {}
        item['width'] = LineString(bbox[0:2]).length
        item['height'] = LineString(bbox[1:3]).length
        item['area'] = item['width'] * item['height']
        item['fontsize'] = 1.0 * item['width'] / len(text)
        item['bbox'] = _norm_bbox(bbox)            
        item['text'] = text
        item['conf'] = float(conf)
        items.append(item)
    return items     

def read_text(img):
    return process_ocr(reader.readtext(img))

# %% [markdown]
# ### Data exploration
# #### First, we will pick some random test slide and will extract any instance of text on it

# %%
from IPython.display import display, JSON, Image as IImage

def draw_boxes(frame, boxes):
    for box in boxes:
        frame = cv2.rectangle(frame, (box[2], box[0]), (box[3], box[1]), (36,255,12), 2)
    return frame

# Load some test image and read the text on it
slide_ = cv2.imread('Test/Images/000033.jpg')

textboxes_ = read_text(slide_)

textdata_ = pd.DataFrame(list(textboxes_))
del textdata_['conf']
             
slide_debug_ = draw_boxes(slide_, [ box['bbox'] for box in textboxes_ ])

display(f"Test slide #33", 
    Image.fromarray(slide_debug_).resize((640,360)), textdata_.head(5))
# Out:
# 'Test slide #33'
# <PIL.Image.Image image mode=RGB size=640x360 at 0x7F4B0C834F10>
#    width  height     area   fontsize                  bbox
# 0  602.0    42.0  25284.0  14.682927     [19, 61, 11, 613]  \
# 1   62.0    16.0    992.0   6.200000    [65, 81, 313, 375]
# 2   82.0    14.0   1148.0   6.307692    [65, 79, 455, 537]
# 3   60.0    16.0    960.0   6.666667  [123, 139, 599, 659]
# 4  110.0    16.0   1760.0   6.875000   [167, 183, 99, 209]
#
#                                         text
# 0  We have many touch receptors in our skinl
# 1                                 Hairy skin
# 2                              Glabrous skin
# 3                                  Epidermis
# 4                           Epidermal-dermal

# %% [markdown]
# #### Now, we will apply finetuned DeepLab model and "score" each textbox as to whether it might be a title or not

# %%
out, scores = titlesegment(slide_, [ box['bbox'] for box in textboxes_ ])
out_mask = (np.abs(out.cpu().numpy())*255).astype(np.uint8)

textdata_['score'] = scores

display(f"Test slide #33 (segmentation output)", Image.fromarray(out_mask).resize((640,360)), textdata_.head(5))
# Out:
# 'Test slide #33 (segmentation output)'
# <PIL.Image.Image image mode=L size=640x360 at 0x7F4B03203EB0>
#    width  height     area   fontsize                  bbox
# 0  602.0    42.0  25284.0  14.682927     [19, 61, 11, 613]  \
# 1   62.0    16.0    992.0   6.200000    [65, 81, 313, 375]
# 2   82.0    14.0   1148.0   6.307692    [65, 79, 455, 537]
# 3   60.0    16.0    960.0   6.666667  [123, 139, 599, 659]
# 4  110.0    16.0   1760.0   6.875000   [167, 183, 99, 209]
#
#                                         text     score
# 0  We have many touch receptors in our skinl  0.877897
# 1                                 Hairy skin  0.038991
# 2                              Glabrous skin  0.063353
# 3                                  Epidermis -0.002464
# 4                           Epidermal-dermal -0.008711

# %% [markdown]
# #### Iterate this method on all test images

# %%
images = sorted(glob.glob('Test/Images/*.jpg'))
result = []

for path in images:
    image = cv2.imread(path)
    textboxes = read_text(image)

    out, scores = titlesegment(image, [ box['bbox'] for box in textboxes ])
    titleboxes = pickonetitle(textboxes, scores)
    
    # Sort text boxes as you would read it in English: from top to bottom
    # and from left to right
    titleboxes = sort_boxes(titleboxes)
    title = ' '.join(box['text'] for box in titleboxes)    
    
    image_id = int(path.split('.')[0].split('/')[-1])
    result.append([image_id, title])

# %% [markdown]
# #### Convert the result to a dataframe and save it

# %%
df = pd.DataFrame.from_records(result, columns=['ID','Title'])
df
# Out:
#       ID                                              Title
# 0      0                        Dissecting Algorithmic Bias
# 1      1                          Algorithms in health care
# 2      2  An algorithm that scales up racial bias A bias...
# 3      3          Targeting extra help for complex patients
# 4      4                   How allocation works in practice
# ..   ...                                                ...
# 285  285                          Data Sharing to Regulator
# 286  286                          Data Sharing to Regulator
# 287  287                                          Thank You
# 288  288                                           DD/MM/YY
# 289  289                                           DD/MM/YY
#
# [290 rows x 2 columns]

# %%
df.to_csv('Submission.csv', index=False)
